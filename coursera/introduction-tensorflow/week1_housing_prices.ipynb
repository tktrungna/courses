# %% [markdown]
# In this exercise you'll try to build a neural network that predicts the price of a house according to a simple formula.
#
# So, imagine if house pricing was as easy as a house costs 50k + 50k per bedroom, so that a 1 bedroom house costs 100k, a 2 bedroom house costs 150k etc.
#
# How would you create a neural network that learns this relationship so that it would predict a 7 bedroom house as costing close to 400k etc.
#
# Hint: Your network might work better if you scale the house price down. You don't have to give the answer 400...it might be better to create something that predicts the number 4, and then your answer is in the 'hundreds of thousands' etc.

# %%
# To support both python 2 and python 3
from __future__ import division, print_function, unicode_literals

import tensorflow as tf
import numpy as np
from tensorflow import keras

xs = np.array([1,2], dtype=float)
ys = np.array([1,1.5], dtype=float)

# %%
model = tf.keras.Sequential(
    [keras.layers.Dense(units=1, input_shape=[1])]
)
model.compile(optimizer='sgd', loss='mean_squared_error')
model.fit(xs, ys, epochs=100)
print(model.predict([7]))
# Out:
# Train on 2 samples
# Epoch 1/100
# 2/2 [==============================] - 0s 171ms/sample - loss: 0.3267
# Epoch 2/100
# 2/2 [==============================] - 0s 718us/sample - loss: 0.2890
# Epoch 3/100
# 2/2 [==============================] - 0s 1ms/sample - loss: 0.2562
# Epoch 4/100
# 2/2 [==============================] - 0s 1ms/sample - loss: 0.2278
# Epoch 5/100
# 2/2 [==============================] - 0s 1ms/sample - loss: 0.2032
# Epoch 6/100
# 2/2 [==============================] - 0s 2ms/sample - loss: 0.1817
# Epoch 7/100
# 2/2 [==============================] - 0s 896us/sample - loss: 0.1631
# Epoch 8/100
# 2/2 [==============================] - 0s 919us/sample - loss: 0.1470
# Epoch 9/100
# 2/2 [==============================] - 0s 880us/sample - loss: 0.1329
# Epoch 10/100
# 2/2 [==============================] - 0s 1ms/sample - loss: 0.1208
# Epoch 11/100
# 2/2 [==============================] - 0s 1ms/sample - loss: 0.1102
# Epoch 12/100
# 2/2 [==============================] - 0s 1ms/sample - loss: 0.1010
# Epoch 13/100
# 2/2 [==============================] - 0s 1ms/sample - loss: 0.0930
# Epoch 14/100
# 2/2 [==============================] - 0s 3ms/sample - loss: 0.0860
# Epoch 15/100
# 2/2 [==============================] - 0s 4ms/sample - loss: 0.0799
# Epoch 16/100
# 2/2 [==============================] - 0s 3ms/sample - loss: 0.0747
# Epoch 17/100
# 2/2 [==============================] - 0s 4ms/sample - loss: 0.0701
# Epoch 18/100
# 2/2 [==============================] - 0s 2ms/sample - loss: 0.0661
# Epoch 19/100
# 2/2 [==============================] - 0s 861us/sample - loss: 0.0626
# Epoch 20/100
# 2/2 [==============================] - 0s 1ms/sample - loss: 0.0596
# Epoch 21/100
# 2/2 [==============================] - 0s 4ms/sample - loss: 0.0569
# Epoch 22/100
# 2/2 [==============================] - 0s 1ms/sample - loss: 0.0546
# Epoch 23/100
# 2/2 [==============================] - 0s 2ms/sample - loss: 0.0526
# Epoch 24/100
# 2/2 [==============================] - 0s 2ms/sample - loss: 0.0508
# Epoch 25/100
# 2/2 [==============================] - 0s 2ms/sample - loss: 0.0493
# Epoch 26/100
# 2/2 [==============================] - 0s 3ms/sample - loss: 0.0479
# Epoch 27/100
# 2/2 [==============================] - 0s 991us/sample - loss: 0.0467
# Epoch 28/100
# 2/2 [==============================] - 0s 2ms/sample - loss: 0.0457
# Epoch 29/100
# 2/2 [==============================] - 0s 2ms/sample - loss: 0.0447
# Epoch 30/100
# 2/2 [==============================] - 0s 2ms/sample - loss: 0.0439
# Epoch 31/100
# 2/2 [==============================] - 0s 1ms/sample - loss: 0.0432
# Epoch 32/100
# 2/2 [==============================] - 0s 2ms/sample - loss: 0.0425
# Epoch 33/100
# 2/2 [==============================] - 0s 818us/sample - loss: 0.0420
# Epoch 34/100
# 2/2 [==============================] - 0s 939us/sample - loss: 0.0415
# Epoch 35/100
# 2/2 [==============================] - 0s 1ms/sample - loss: 0.0410
# Epoch 36/100
# 2/2 [==============================] - 0s 2ms/sample - loss: 0.0406
# Epoch 37/100
# 2/2 [==============================] - 0s 859us/sample - loss: 0.0402
# Epoch 38/100
# 2/2 [==============================] - 0s 913us/sample - loss: 0.0399
# Epoch 39/100
# 2/2 [==============================] - 0s 1ms/sample - loss: 0.0396
# Epoch 40/100
# 2/2 [==============================] - 0s 1ms/sample - loss: 0.0393
# Epoch 41/100
# 2/2 [==============================] - 0s 2ms/sample - loss: 0.0390
# Epoch 42/100
# 2/2 [==============================] - 0s 835us/sample - loss: 0.0388
# Epoch 43/100
# 2/2 [==============================] - 0s 738us/sample - loss: 0.0386
# Epoch 44/100
# 2/2 [==============================] - 0s 1ms/sample - loss: 0.0384
# Epoch 45/100
# 2/2 [==============================] - 0s 1ms/sample - loss: 0.0382
# Epoch 46/100
# 2/2 [==============================] - 0s 1ms/sample - loss: 0.0380
# Epoch 47/100
# 2/2 [==============================] - 0s 987us/sample - loss: 0.0378
# Epoch 48/100
# 2/2 [==============================] - 0s 1ms/sample - loss: 0.0376
# Epoch 49/100
# 2/2 [==============================] - 0s 1ms/sample - loss: 0.0375
# Epoch 50/100
# 2/2 [==============================] - 0s 808us/sample - loss: 0.0373
# Epoch 51/100
# 2/2 [==============================] - 0s 2ms/sample - loss: 0.0372
# Epoch 52/100
# 2/2 [==============================] - 0s 814us/sample - loss: 0.0371
# Epoch 53/100
# 2/2 [==============================] - 0s 809us/sample - loss: 0.0369
# Epoch 54/100
# 2/2 [==============================] - 0s 1ms/sample - loss: 0.0368
# Epoch 55/100
# 2/2 [==============================] - 0s 2ms/sample - loss: 0.0367
# Epoch 56/100
# 2/2 [==============================] - 0s 950us/sample - loss: 0.0365
# Epoch 57/100
# 2/2 [==============================] - 0s 735us/sample - loss: 0.0364
# Epoch 58/100
# 2/2 [==============================] - 0s 2ms/sample - loss: 0.0363
# Epoch 59/100
# 2/2 [==============================] - 0s 1ms/sample - loss: 0.0362
# Epoch 60/100
# 2/2 [==============================] - 0s 706us/sample - loss: 0.0361
# Epoch 61/100
# 2/2 [==============================] - 0s 979us/sample - loss: 0.0360
# Epoch 62/100
# 2/2 [==============================] - 0s 911us/sample - loss: 0.0358
# Epoch 63/100
# 2/2 [==============================] - 0s 2ms/sample - loss: 0.0357
# Epoch 64/100
# 2/2 [==============================] - 0s 1ms/sample - loss: 0.0356
# Epoch 65/100
# 2/2 [==============================] - 0s 1ms/sample - loss: 0.0355
# Epoch 66/100
# 2/2 [==============================] - 0s 1ms/sample - loss: 0.0354
# Epoch 67/100
# 2/2 [==============================] - 0s 884us/sample - loss: 0.0353
# Epoch 68/100
# 2/2 [==============================] - 0s 2ms/sample - loss: 0.0352
# Epoch 69/100
# 2/2 [==============================] - 0s 759us/sample - loss: 0.0351
# Epoch 70/100
# 2/2 [==============================] - 0s 1ms/sample - loss: 0.0350
# Epoch 71/100
# 2/2 [==============================] - 0s 1ms/sample - loss: 0.0349
# Epoch 72/100
# 2/2 [==============================] - 0s 2ms/sample - loss: 0.0348
# Epoch 73/100
# 2/2 [==============================] - 0s 2ms/sample - loss: 0.0347
# Epoch 74/100
# 2/2 [==============================] - 0s 1ms/sample - loss: 0.0346
# Epoch 75/100
# 2/2 [==============================] - 0s 1ms/sample - loss: 0.0345
# Epoch 76/100
# 2/2 [==============================] - 0s 717us/sample - loss: 0.0344
# Epoch 77/100
# 2/2 [==============================] - 0s 2ms/sample - loss: 0.0343
# Epoch 78/100
# 2/2 [==============================] - 0s 821us/sample - loss: 0.0342
# Epoch 79/100
# 2/2 [==============================] - 0s 800us/sample - loss: 0.0341
# Epoch 80/100
# 2/2 [==============================] - 0s 1ms/sample - loss: 0.0340
# Epoch 81/100
# 2/2 [==============================] - 0s 2ms/sample - loss: 0.0339
# Epoch 82/100
# 2/2 [==============================] - 0s 1ms/sample - loss: 0.0338
# Epoch 83/100
# 2/2 [==============================] - 0s 1ms/sample - loss: 0.0337
# Epoch 84/100
# 2/2 [==============================] - 0s 1ms/sample - loss: 0.0336
# Epoch 85/100
# 2/2 [==============================] - 0s 1000us/sample - loss: 0.0335
# Epoch 86/100
# 2/2 [==============================] - 0s 812us/sample - loss: 0.0334
# Epoch 87/100
# 2/2 [==============================] - 0s 1ms/sample - loss: 0.0333
# Epoch 88/100
# 2/2 [==============================] - 0s 2ms/sample - loss: 0.0332
# Epoch 89/100
# 2/2 [==============================] - 0s 811us/sample - loss: 0.0331
# Epoch 90/100
# 2/2 [==============================] - 0s 746us/sample - loss: 0.0330
# Epoch 91/100
# 2/2 [==============================] - 0s 722us/sample - loss: 0.0329
# Epoch 92/100
# 2/2 [==============================] - 0s 850us/sample - loss: 0.0328
# Epoch 93/100
# 2/2 [==============================] - 0s 2ms/sample - loss: 0.0327
# Epoch 94/100
# 2/2 [==============================] - 0s 2ms/sample - loss: 0.0326
# Epoch 95/100
# 2/2 [==============================] - 0s 1ms/sample - loss: 0.0325
# Epoch 96/100
# 2/2 [==============================] - 0s 936us/sample - loss: 0.0324
# Epoch 97/100
# 2/2 [==============================] - 0s 1ms/sample - loss: 0.0323
# Epoch 98/100
# 2/2 [==============================] - 0s 1ms/sample - loss: 0.0322
# Epoch 99/100
# 2/2 [==============================] - 0s 1ms/sample - loss: 0.0321
# Epoch 100/100
# 2/2 [==============================] - 0s 1ms/sample - loss: 0.0320
# [[5.873687]]
